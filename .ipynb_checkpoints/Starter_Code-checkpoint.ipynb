# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
drop_EIN=application_df.drop("EIN",axis=1)
drop_Name=drop_EIN.drop("NAME",axis=1)
drop_Name.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
Unique_values=drop_Name.nunique()
Unique_values
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
app_value_count=drop_Name['APPLICATION_TYPE'].value_counts()
app_value_count
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T15        2
# T29        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
application_types_to_replace=['T9','T13','T12','T2','T25','T14','T29','T15','T17']
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
Class_value_count=drop_Name['CLASSIFICATION'].value_counts()
Class_value_count
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C8210        1
# C4500        1
# C1236        1
# C2561        1
# C3700        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
Class_value_count_greater_than_one=Class_value_count[Class_value_count>1]
Class_value_count_greater_than_one
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C2300       32
# C7200       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C4100        6
# C2400        6
# C1720        6
# C1600        5
# C1257        5
# C0           3
# C1260        3
# C2710        3
# C3200        2
# C1267        2
# C1256        2
# C1234        2
# C1246        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace=list(Class_value_count[Class_value_count<1883].index)
# classifications_to_replace
# # # Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
#     print (cls)
# # Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
numeric_data=pd.get_dummies(drop_Name)
numeric_data.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  APPLICATION_TYPE_T12  \
# 0       1     5000              1                     1                     0
# 1       1   108590              1                     0                     0
# 2       1     5000              0                     0                     0
# 3       1     6692              1                     0                     0
# 4       1   142590              1                     0                     0
#
#    APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  APPLICATION_TYPE_T15  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  ...  INCOME_AMT_1-9999  \
# ...

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
y=numeric_data['IS_SUCCESSFUL']
X=numeric_data.drop('IS_SUCCESSFUL',axis=1).values
# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test= train_test_split(X,y,random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()
input_dimension=len(X_train[0])
input_dimension
# # First hidden layer
# #  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=80,input_dim=input_dimension,activation="relu"))
# Second hidden layer
# #  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=30,activation="relu"))

# # Output layer
# #  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1,activation="sigmoid"))
# # Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 80)                9360
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                2430
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 31
# ...
# Total params: 11,821
# Trainable params: 11,821
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

fit_model = nn.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5299 - accuracy: 0.7437
# Epoch 2/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5253 - accuracy: 0.7433
# Epoch 3/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5249 - accuracy: 0.7430
# Epoch 4/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5254 - accuracy: 0.7438
# Epoch 5/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5252 - accuracy: 0.7437
# Epoch 6/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5252 - accuracy: 0.7436
# Epoch 7/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5251 - accuracy: 0.7439:
# Epoch 8/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5253 - accuracy: 0.7431
# Epoch 9/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5249 - accuracy: 0.7443: 1s - l
# Epoch 10/200
# ...

# %%
# Train the model
#  YOUR CODE GOES HERE

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.6138 - accuracy: 0.7299
# Loss: 0.6138195395469666, Accuracy: 0.729912519454956

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save("AlphabetSoupCharity.H5")
# Out:
# INFO:tensorflow:Assets written to: AlphabetSoupCharity.H5/assets

# %%
# Step3: improving the model
# # First hidden layer
nn.add(tf.keras.layers.Dense(units=80,input_dim=input_dimension,activation="relu"))
# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30,activation="relu"))
# Adding another hidden layer
nn.add(tf.keras.layers.Dense(units=30,activation="relu"))
# # Output layer
nn.add(tf.keras.layers.Dense(units=1,activation="sigmoid"))
# # Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 80)                9360
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                2430
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 31
# _________________________________________________________________
# dense_3 (Dense)              (None, 80)                160
# _________________________________________________________________
# dense_4 (Dense)              (None, 30)                2430
# _________________________________________________________________
# dense_5 (Dense)              (None, 30)                930
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 31
# ...

# %%
# Trainig the model 
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

fit_model = nn.fit(X_train_scaled, y_train, epochs=200)
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/200
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5487 - accuracy: 0.7373
# Epoch 2/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5311 - accuracy: 0.7411
# Epoch 3/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5287 - accuracy: 0.7438
# Epoch 4/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5280 - accuracy: 0.7433
# Epoch 5/200
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5277 - accuracy: 0.7434
# Epoch 6/200
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5270 - accuracy: 0.7416
# Epoch 7/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5276 - accuracy: 0.7430
# Epoch 8/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5282 - accuracy: 0.7413
# Epoch 9/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5285 - accuracy: 0.7414
# Epoch 10/200
# ...
